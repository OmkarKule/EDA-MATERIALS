# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("car.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %% [markdown]
# EDA:- Exploratory Data Analysis :- Question :- What is Exploratory Data Analysis?Answer:- Exploratory Data Analysis
# refers to the critical process of performing initial investigations on data so as to discover patterns,to spot anormalies, to test hypothesis & to check assumptions with the help of summary statistics & Graphical representations. for Visaualization.

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type   body-style  \
# 0          3                 ?  alfa-romero       gas  convertible
# 1          3                 ?  alfa-romero       gas  convertible
# 2          1                 ?  alfa-romero       gas    hatchback
# 3          2               164         audi       gas        sedan
# 4          2               164         audi       gas        sedan
#
#   drive-wheels engine-location  width  height engine-type  engine-size  \
# 0          rwd           front   64.1    48.8        dohc          130
# 1          rwd           front   64.1    48.8        dohc          130
# 2          rwd           front   65.5    52.4        ohcv          152
# 3          fwd           front   66.2    54.3         ohc          109
# 4          4wd           front   66.4    54.3         ohc          136
#
#   horsepower  city-mpg  highway-mpg  price
# 0        111        21           27  13495
# 1        111        21           27  16500
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df['normalized-losses']=df['normalized-losses'].replace('?',np.nan)
df['normalized-losses']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
df['normalized-losses']=df['normalized-losses'].astype(float)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3                NaN  alfa-romero       gas  convertible
# 1            3                NaN  alfa-romero       gas  convertible
# 2            1                NaN  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df["normalized-losses"]=df['normalized-losses'].fillna(df["normalized-losses"].mean())
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df["horsepower"]=df['horsepower'].astype(float)
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df["horsepower"]=df['horsepower'].fillna(df["horsepower"].mean())
df
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
#Seabornlib:Seaborn is a Python data Visualization Library based on Metplotlib
#It provide a high -level interface for drawing attarctive and informative statistical graphics.

# %%
df.columns
#a=df['make']
#a
#a.tail(135)
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
df.loc[(df['make']=='isuzu')&(df['price']>20000)] # Required featch drop
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 45          0              122.0  isuzu       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 45           front   63.6    52.0         ohc           90        70.0
#
#     city-mpg  highway-mpg  price
# 45        38           43  23000

# %%
df.drop(45,inplace=True)
df.head(50)
# Out:
#     symboling  normalized-losses         make fuel-type   body-style  \
# 0           3              122.0  alfa-romero       gas  convertible
# 1           3              122.0  alfa-romero       gas  convertible
# 2           1              122.0  alfa-romero       gas    hatchback
# 3           2              164.0         audi       gas        sedan
# 4           2              164.0         audi       gas        sedan
# 5           2              122.0         audi       gas        sedan
# 6           1              158.0         audi       gas        sedan
# 7           1              122.0         audi       gas        wagon
# 8           1              158.0         audi       gas        sedan
# 9           0              122.0         audi       gas    hatchback
# 10          2              192.0          bmw       gas        sedan
# 11          0              192.0          bmw       gas        sedan
# 12          0              188.0          bmw       gas        sedan
# ...

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
df.loc[(df['make']=='honda')&(df['price']>12000)]
# Out:
#     symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 41          0               85.0  honda       gas      sedan          fwd
#
#    engine-location  width  height engine-type  engine-size  horsepower  \
# 41           front   65.2    54.1         ohc          110       101.0
#
#     city-mpg  highway-mpg  price
# 41        24           28  12945

# %%
df.drop(41,inplace=True)
df.head(50)
# Out:
#     symboling  normalized-losses         make fuel-type   body-style  \
# 0           3              122.0  alfa-romero       gas  convertible
# 1           3              122.0  alfa-romero       gas  convertible
# 2           1              122.0  alfa-romero       gas    hatchback
# 3           2              164.0         audi       gas        sedan
# 4           2              164.0         audi       gas        sedan
# 5           2              122.0         audi       gas        sedan
# 6           1              158.0         audi       gas        sedan
# 7           1              122.0         audi       gas        wagon
# 8           1              158.0         audi       gas        sedan
# 9           0              122.0         audi       gas    hatchback
# 10          2              192.0          bmw       gas        sedan
# 11          0              192.0          bmw       gas        sedan
# 12          0              188.0          bmw       gas        sedan
# ...

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
df.loc[(df['make']=='toyota')&(df['price']>13000)]
# Out:
#      symboling  normalized-losses    make fuel-type   body-style drive-wheels  \
# 172          2              134.0  toyota       gas  convertible          rwd
# 178          3              197.0  toyota       gas    hatchback          rwd
# 179          3              197.0  toyota       gas    hatchback          rwd
# 180         -1               90.0  toyota       gas        sedan          rwd
# 181         -1              122.0  toyota       gas        wagon          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 172           front   65.6    53.0         ohc          146       116.0
# 178           front   67.7    52.0        dohc          171       161.0
# 179           front   67.7    52.0        dohc          171       161.0
# 180           front   66.5    54.1        dohc          171       156.0
# 181           front   66.5    54.1        dohc          161       156.0
#
#      city-mpg  highway-mpg  price
# ...

# %%
df.drop([172,178,179,180,181],inplace=True)

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
#Task : Volvo & Price>30000  Fetch & drop Data after the visual data

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %%
df.loc[(df['make']=='volvo')&(df['price']>20000)]
# Out:
#      symboling  normalized-losses   make fuel-type body-style drive-wheels  \
# 202         -1               95.0  volvo       gas      sedan          rwd
# 203         -1               95.0  volvo    diesel      sedan          rwd
# 204         -1               95.0  volvo       gas      sedan          rwd
#
#     engine-location  width  height engine-type  engine-size  horsepower  \
# 202           front   68.9    55.5        ohcv          173       134.0
# 203           front   68.9    55.5         ohc          145       106.0
# 204           front   68.9    55.5         ohc          141       114.0
#
#      city-mpg  highway-mpg  price
# 202        18           23  21485
# 203        26           27  22470
# 204        19           25  22625

# %%
df.drop([202,203,204],inplace=True)

# %%
plt.figure(figsize=(7,8))
sns.boxplot(data=df,x="price",y="make")
plt.grid()
plt.show()

# %% [markdown]
# # Handeling Catagorical Data

# %%
#Convert Categorial data into numerical data.

# %%
df_cat=df.select_dtypes(object)
df_cat.head(500)
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 197        volvo       gas        wagon          rwd           front
# 198        volvo       gas        sedan          rwd           front
# 199        volvo       gas        wagon          rwd           front
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
df_num=df.select_dtypes(['float64','int64'])
df_num
# Out:
#      symboling  normalized-losses  width  height  engine-size  horsepower  \
# 0            3              122.0   64.1    48.8          130       111.0
# 1            3              122.0   64.1    48.8          130       111.0
# 2            1              122.0   65.5    52.4          152       154.0
# 3            2              164.0   66.2    54.3          109       102.0
# 4            2              164.0   66.4    54.3          136       115.0
# ..         ...                ...    ...     ...          ...         ...
# 197         -1               74.0   67.2    57.5          141       114.0
# 198         -2              103.0   67.2    56.2          130       162.0
# 199         -1               74.0   67.2    57.5          130       162.0
# 200         -1               95.0   68.9    55.5          141       114.0
# 201         -1               95.0   68.8    55.5          141       160.0
#
#      city-mpg  highway-mpg  price
# 0          21           27  13495
# ...

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 201
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          195 non-null    int64
#  1   normalized-losses  195 non-null    float64
#  2   width              195 non-null    float64
#  3   height             195 non-null    float64
#  4   engine-size        195 non-null    int64
#  5   horsepower         195 non-null    float64
#  6   city-mpg           195 non-null    int64
#  7   highway-mpg        195 non-null    int64
#  8   price              195 non-null    int64
# dtypes: float64(4), int64(5)
# memory usage: 15.2 KB

# %%
df_cat.head(200)
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 197        volvo       gas        wagon          rwd           front
# 198        volvo       gas        sedan          rwd           front
# 199        volvo       gas        wagon          rwd           front
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
#
#     engine-type
# 0          dohc
# 1          dohc
# 2          ohcv
# 3           ohc
# 4           ohc
# ..          ...
# ...

# %%
df_cat['fuel-type'].value_counts() #-----2 Columns added.
# Out:
# gas       176
# diesel     19
# Name: fuel-type, dtype: int64

# %%
#First approch that is one hot encoding to handle categorical data

# %%
df_fuel=pd.get_dummies(df_cat['fuel-type'])
df_fuel
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 197       0    1
# 198       0    1
# 199       0    1
# 200       0    1
# 201       0    1
#
# [195 rows x 2 columns]

# %%
# second approach that is label encoder to handle categorical data

# %%
# what is scikit-learn?
# scikit learn is an oepn source machine learning python package that offers functionality
# supporting supervised and unsupervised learning. Additionally, it provides tools for model development, selection 
# evalution as well as many other utilities including data pre- processing functionality..

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_cat['fuel-type_num']=le.fit_transform(df_cat['fuel-type'])
df_cat['fuel-type_num']
#df_cat['make_num']=le.fit_transform(df_cat['make'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 197    1
# 198    1
# 199    1
# 200    1
# 201    1
# Name: fuel-type_num, Length: 195, dtype: int32

# %%
df_cat
# Out:
#             make fuel-type   body-style drive-wheels engine-location  \
# 0    alfa-romero       gas  convertible          rwd           front
# 1    alfa-romero       gas  convertible          rwd           front
# 2    alfa-romero       gas    hatchback          rwd           front
# 3           audi       gas        sedan          fwd           front
# 4           audi       gas        sedan          4wd           front
# ..           ...       ...          ...          ...             ...
# 197        volvo       gas        wagon          rwd           front
# 198        volvo       gas        sedan          rwd           front
# 199        volvo       gas        wagon          rwd           front
# 200        volvo       gas        sedan          rwd           front
# 201        volvo       gas        sedan          rwd           front
#
#     engine-type  fuel-type_num
# 0          dohc              1
# 1          dohc              1
# 2          ohcv              1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 201
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          195 non-null    int64
#  1   normalized-losses  195 non-null    float64
#  2   make               195 non-null    object
#  3   fuel-type          195 non-null    object
#  4   body-style         195 non-null    object
#  5   drive-wheels       195 non-null    object
#  6   engine-location    195 non-null    object
#  7   width              195 non-null    float64
#  8   height             195 non-null    float64
#  9   engine-type        195 non-null    object
#  10  engine-size        195 non-null    int64
#  11  horsepower         195 non-null    float64
#  12  city-mpg           195 non-null    int64
#  13  highway-mpg        195 non-null    int64
#  14  price              195 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %% [markdown]
# # How to remove Skewness

# %%
# What's Skewness?
# Understanding Skewness
# Besides positive and negative skew, distributions can also be said to 
# have zero or undefined skew. 
# In the curve of a distribution, the data on the right side of the 
# curve may taper differently from the data on 
# the left side. These taperings are known as "tails." Negative skew 
# refers to a longer or fatter tail on the left side 
# of the distribution,while positive skew refers to a longer or fatter 
# tail on the right.

# %%
from scipy.stats import skew

# %%
print("Skewness ",skew(df['normalized-losses']))
sns.distplot(df['normalized-losses'])
plt.show()
# Out:
# Skewness  0.8210643534017881
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4952\3295367344.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['normalized-losses'])

# %%
print("Skewness ",skew(df['height']))
sns.distplot(df['height'])
plt.show()
# Out:
# Skewness  0.06562575476931899
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4952\214633444.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['height'])

# %%
df['normalized-losses']=np.sqrt(df['normalized-losses'])

# %%
print("Skewness ",skew(df['normalized-losses']))
sns.distplot(df['normalized-losses'])
plt.show()
# Out:
# Skewness  0.3764027983184205
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4952\3295367344.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['normalized-losses'])

# %% [raw]
# Scalling MinMaxScaler(feature_range = (0, 1)) will transform each value in the column proportionally within the range [0,1]. Use this as the first scaler choice to transform a feature, as it will preserve the shape of the dataset (no distortion).
#
# StandardScaler() will transform each value in the column to range about the mean 0 and standard deviation 1, ie, each value will be normalised by subtracting the mean and dividing by standard deviation. Use StandardScaler if you know the data distribut is normal.

# %% [markdown]
# When MinMaxScaler is used the it is also known as Normalization and it transform all the values in range between (0 to 1) formula is x = [(value - min)/(Max- Min)]
#
# StandardScaler comes under Standardization and its value ranges between (-3 to +3) formula is z = [(x - x.mean)/Std_deviation]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
ss.fit_transform(df[['height']])
# mm=MinMaxScaler()
# mm.fit_transform(df[['height']])
# Out:
# array([[-1.98520535],
#        [-1.98520535],
#        [-0.53322144],
#        [ 0.2331034 ],
#        [ 0.2331034 ],
#        [-0.25089124],
#        [ 0.79776381],
#        [ 0.79776381],
#        [ 0.87842958],
#        [-0.69455299],
#        [ 0.2331034 ],
#        [ 0.2331034 ],
#        [ 0.2331034 ],
#        [ 0.2331034 ],
#        [ 0.79776381],
#        [ 0.79776381],
#        [-0.00889392],
#        [ 1.03976113],
#        [-0.21055835],
#        [-0.69455299],
#        [-0.69455299],
#        [-1.17854762],
#        [-1.17854762],
#        [-1.17854762],
#        [-1.2592134 ],
#        [-1.2592134 ],
#        [-1.2592134 ],
#        [-1.2592134 ],
#        [ 2.45141215],
#        [-1.42054494],
#        [-1.17854762],
#        [-1.17854762],
#        [-0.45255567],
#        [-0.45255567],
#        [-0.45255567],
#        [ 0.31376917],
#        [ 1.84641886],
#        [-0.17022546],
#        [-0.17022546],
#        [ 0.15243763],
#        [ 0.15243763],
# ...
